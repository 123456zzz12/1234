# %%
# !python detect.py --source D:/FallDataset/Lecture_room/video(1).avi
# Out:
# detect: weights=C:/Users/ccq/yolov5-master/runs/train/exp/weights/best.pt, source=D:/FallDataset/Lecture_room/video(1).avi, data=mydata\ABCD.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-4-24 torch 1.10.1 CUDA:0 (NVIDIA GeForce MX150, 2048MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7015519 parameters, 0 gradients
# video 1/1 (1/285) D:\FallDataset\Lecture_room\video(1).avi: 480x640 Done. (0.034s)
# video 1/1 (2/285) D:\FallDataset\Lecture_room\video(1).avi: 480x640 Done. (0.034s)
# video 1/1 (3/285) D:\FallDataset\Lecture_room\video(1).avi: 480x640 Done. (0.031s)
# ...
